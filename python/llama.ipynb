# %% [markdown]
# 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

# %% [markdown]
# !pip install requests

# %%
user_input = input("Enter your message: ")

# %%
import requests
import json

# Set your API key
OPENROUTER_API_KEY = "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"

response = requests.post(
    url="https://openrouter.ai/api/v1/chat/completions",
    headers={
        "Authorization": f"Bearer {OPENROUTER_API_KEY}",
    },
    data=json.dumps({
        "model": "openai/gpt-3.5-turbo",  # Specify the model if needed
        "messages": [
            {"role": "user", "content": user_input}
        ]
    })
)

# Check the response
if response.status_code == 200:
    response_data = response.json()
    print(json.dumps(response_data, indent=2))
else:
    print(f"Error: {response.status_code}")
    print(response.text)
# Out:
# {
#   "id": "gen-a5VAfsaqAUeh74adD4DzOgBd4MwC",
#   "model": "openai/gpt-3.5-turbo",
#   "object": "chat.completion",
#   "created": 1724405513,
#   "choices": [
#     {
#       "logprobs": null,
#       "finish_reason": "stop",
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "I'm not sure what you mean by \"cmds.\" Could you please provide more context or clarify your question?",
#         "refusal": ""
#       }
#     }
#   ],
#   "system_fingerprint": null,
#   "usage": {
#     "prompt_tokens": 8,
#     "completion_tokens": 22,
#     "total_tokens": 30
#   }
# }

# %%
content = response_data["choices"][0]["message"]["content"]
print(content)
# Out:
# I'm not sure what you mean by "cmds." Could you please provide more context or clarify your question?
